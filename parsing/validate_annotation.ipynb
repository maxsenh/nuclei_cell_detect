# %% [markdown]
# # Validate annotation and masks to images

# %%
import os
import json
import random

# %%
ANNO = "/data/proj/smFISH/Students/Max_Senftleben/files/annotation/"

IMAGES = "/data/proj/smFISH/Students/Max_Senftleben/files/data/"

print(os.listdir(ANNO + 'nuclei_20181107/'))
print(os.listdir(ANNO + 'new_nuclei/'))
# Out:
# ['train_coco_nuclei_new.json', 'val_coco_nuclei_new.json', 'test_coco_nuclei_new.json', 'train_coco_nuclei.json', 'val_coco_nuclei.json', 'test_coco_nuclei.json']
# ['nuclei_20190205.json', 'train_coco.json', 'val_coco.json', 'test_coco.json', 'train_coco_id.json', 'test_coco_id.json', 'val_coco_id.json']

# %%
img_path = IMAGES + 'nuclei_20190205_data/train/' # old
img_path = IMAGES + 'nuclei_20181107/train/' # resized



def boxes_segm(anno_list, image_id):
    box_list = []
    segm_list = []
    for i, anno_dict in enumerate(anno_list):
        if anno_dict['image_id'] == image_id:
            box_list.append(anno_dict['bbox'])
            segm_list.append(anno_dict['segmentation'])
    return box_list, segm_list

def handle_box_list(box_list):

# %%
coco_dict = json.load(open(ANNO + 'new_nuclei/train_coco_id.json'))
anno_list = coco_dict['annotations']
img_list = coco_dict['images']

# one image
rnd_img = random.choice(img_list)['id']
segm_list, bbox_list = boxes_segm(anno_list, rnd_img)

# %%
chunks_to_save_dir = "/data/proj/smFISH/Students/Max_Senftleben/files/data/" + 'nuclei_20181107_data/test/'

import matplotlib.pyplot as plt
import os
import matplotlib.image as mpimg
import numpy

for file in os.listdir(chunks_to_save_dir):
    img=mpimg.imread(chunks_to_save_dir + file)
    imgplot = plt.imshow(img)
    plt.show()
